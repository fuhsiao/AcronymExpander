# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/src')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import pandas as pd

# %%
def load_json(path):
  with open(path) as f:
    data = json.load(f)
  return data

def build_dataset(data, diction):
  rows = []
  for row in data:
    acronym = row['acronym']
    tokens = row['tokens']
    expansion = row['expansion']
    sentence = ' '.join(tokens)
    acronym_token = tokens[acronym]

    # define row format
    row['acronym_token'] = acronym_token
    row['sentence'] = sentence
    row['label'] = True
    rows.append(row)

    # Duplicate rows corresponding to the incorrect expansion
    possible_expansions = diction[acronym_token]
    for possible_expansion in possible_expansions:
      if possible_expansion != expansion:
        error_row = row.copy()
        error_row['expansion'] = possible_expansion
        error_row['label'] = False
        rows.append(error_row)

  return pd.DataFrame(rows, columns=['acronym_token', 'expansion', 'sentence', 'label'])

# %%
data = load_json('../dataset/raw/dev.json')
diction = load_json('../dataset/diction.json')
dataset = build_dataset(data, diction)
dataset
# Out:
#       acronym_token                     expansion  \
# 0                FL            federated learning
# 1                FL                 flatten layer
# 2                FL             fixated locations
# 3                RF                 random forest
# 4                RF               radio frequency
# ...             ...                           ...
# 28281            LP            linear programming
# 28282            LP                label powerset
# 28283            LP             label propagation
# 28284           CFD  computational fluid dynamics
# 28285           CFD  carrier frequency difference
#
#                                                 sentence  label
# 0      In , we investigated the FL loss function mini...   True
# 1      In , we investigated the FL loss function mini...  False
# 2      In , we investigated the FL loss function mini...  False
# 3      The nature of the regression algorithm makes t...   True
# 4      The nature of the regression algorithm makes t...  False
# ...                                                  ...    ...
# 28281  On the other hand , since is symmetric , and i...   True
# 28282  On the other hand , since is symmetric , and i...  False
# 28283  On the other hand , since is symmetric , and i...  False
# 28284  Incidentally , the MAP estimate matches more c...   True
# 28285  Incidentally , the MAP estimate matches more c...  False
#
# [28286 rows x 4 columns]

# %%
shuffled_df = dataset.sample(frac=1, random_state=42)
split_point = 22720
training_set = shuffled_df.iloc[:split_point]
testing_set = shuffled_df.iloc[split_point:]

# %%
training_set.to_parquet('../dataset/parquet/train.parquet', index=False)
testing_set.to_parquet('../dataset/parquet/test.parquet', index=False)
